# %%
# !pip install torch torchvision pillow --quiet

# %%
import torch
from torchvision import models, transforms
from PIL import Image

# Load pretrained AI model
model = models.resnet18(pretrained=True)
model.eval()

# Image transformation
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor()
])

# Download labels
# !wget -q https://raw.githubusercontent.com/pytorch/hub/master/imagenet_classes.txt

# Read labels
with open("imagenet_classes.txt") as f:
    labels = [line.strip() for line in f.readlines()]

# List of images
images = ["cat.jpg", "puppy.jpg"]

# Predict each image
for image_name in images:

    img = Image.open(image_name)

    img_t = transform(img)

    batch_t = torch.unsqueeze(img_t, 0)

    out = model(batch_t)

    _, index = torch.max(out, 1)

    print(f"{image_name} --> {labels[index.item()]}")
# Out:
# cat.jpg --> Persian cat
# puppy.jpg --> beagle
